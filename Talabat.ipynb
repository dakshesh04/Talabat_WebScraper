# %%
from bs4 import BeautifulSoup as bs
import requests
import json
import pandas as pd
import csv

# %%
def load_data(title):
    with open(title, encoding = 'utf-8') as f:
        return json.load(f)

def save_data(title, data):
    with open(title, 'a', encoding = 'utf-8') as f:
        json.dump(data, f, ensure_ascii = False, indent=2)

# %%
def menu_details(r):
    
    items_name = []
    items_des = []
    items_price = []
    items_logo = []
    R_info_list = load_data("menu.json") # load data
    page = R_info_list['pageProps']
    menu_state = page['initialMenuState']
    menu = menu_state['menuData']
    items = menu['items']
    for index,i in enumerate(items):
        items_name.append(i['name'])
        items_des.append(i['description'])
        items_price.append(i['price'])
        items_logo.append(i['image'])
    
    # Setting the details into a dataframe
    df1 = (pd.DataFrame(items_name)).transpose()
    df2 = (pd.DataFrame(items_des)).transpose()
    df3 = (pd.DataFrame(items_price)).transpose()
    df4 = (pd.DataFrame(items_logo)).transpose()
    df = df1.append(df2)
    df = df.append(df3)
    df = df.append(df4)
    df = df.transpose()
    # saving the dataframe to csv
    df.to_csv('menu_list.csv',encoding='utf-8')
    
    # saving the details to json file
    save_data('menu_list.json',r) # Restaurant's name
    save_data('menu_list.json',items_name)
    save_data('menu_list.json',items_des)
    save_data('menu_list.json',items_price)
    save_data('menu_list.json',items_logo)
    
    
def restaurant_details():
    Rest_details = {}
    R_info_list = load_data("menu.json") # load data
    page = R_info_list['pageProps']
    event = page['gtmEventData']
    rest = event['restaurant']
    Rest_details['name'] = rest['name']
    Rest_details['logo'] = rest['logo']
    Rest_details['latitude']= rest['latitude']
    Rest_details['longitude'] = rest['longitude']
    Rest_details['cuisine_tags'] = rest['cuisineString']
    csv_writer.writerow([Rest_details['name'],Rest_details['logo'],Rest_details['latitude'],Rest_details['longitude'],Rest_details['cuisine_tags']])
    save_data('Restaurant.json',Rest_details)
    return Rest_details['name']

# %%
#sample = load_data("sample.json") # using sample data
#sample = load_data("my_data.json") # Experimental data -  used on running the second time
csv_file = open('cms_scrape.csv','w')
csv_writer = csv.writer(csv_file)
csv_writer.writerow(['Name','Logo','Latitude','Longitude','Cuisine tags'])
for s in sample:
    
    #print(s)
    site = (s[8:]).split('/')
    #print(site)
    countrySlug = site[1]
    vertical = site[2]
    branchId = site[3]
    payload = "aid=1308&countrySlug="+countrySlug+"&vertical="+vertical+"&branchId="+branchId
    url = "https://www.talabat.com/_next/data/0ec73ce4-edc7-45e4-a589-850f01f4a4d9/menu.json?"+payload
    print(url)
    r =requests.get(url)
    menu = r.json()
    with open("Menu.json", 'w') as f:
        json.dump(menu, f)
    
    R_name = restaurant_details()
    menu_details(R_name)

csv_file.close()
csv_f2.close()
# Out:
# https://www.talabat.com/_next/data/0ec73ce4-edc7-45e4-a589-850f01f4a4d9/menu.json?aid=1308&countrySlug=uae&vertical=restaurant&branchId=47532
# https://www.talabat.com/_next/data/0ec73ce4-edc7-45e4-a589-850f01f4a4d9/menu.json?aid=1308&countrySlug=uae&vertical=restaurant&branchId=12291
# https://www.talabat.com/_next/data/0ec73ce4-edc7-45e4-a589-850f01f4a4d9/menu.json?aid=1308&countrySlug=uae&vertical=restaurant&branchId=617350
# https://www.talabat.com/_next/data/0ec73ce4-edc7-45e4-a589-850f01f4a4d9/menu.json?aid=1308&countrySlug=uae&vertical=restaurant&branchId=615320

# %%
# Out:
#                                          0  \
# 0                      Gino's Meal for One
# 1                        Gino's Meal for 2
# 2                   Family Meal (Serves 4)
# 3                      Appetizer Share Box
# 4                           Any 3 Panuozzo
# 5                     Ginos Chicken Strips
# 6                       Sweet Potato Fries
# 7                      Ginos Potato Wedges
# 8                         Mozzarella Balls
# 9                Garlic Bread & Mozzarella
# 10                Gino's Chicken Wings (6)
# 11                                Arancini
# 12                      Quinoa Greco Salad
# 13             Italian Chicken Pasta Salad
# 14              Ginos Chicken Caesar Salad
# 15          Tomato & Mozzarella (Sandwich)
# 16                  Salami Melt (Sandwich)
# 17             Fire Chicken BBQ (Sandwich)
# 18     Chicken Pesto Mozzarella (Sandwich)
# 19             Italian Meatball (Sandwich)
# 20            Bresaola & Rocket (Sandwich)
# 21     Butter Chicken & Burrata (Sandwich)
# 22  Halloumi & Roast Vegetables (Sandwich)
# 23         Chipotle Cheesesteak (Sandwich)
# 24              Buffalo Chicken (Sandwich)
# 25                    Tuna Mayo (Sandwich)
# 26            BBQ Honey Mustard (Sandwich)
# 27               Classic Reuben (Sandwich)
# 28                  The Rebecca (Sandwich)
# 29                Brooklyn Hero (Sandwich)
# 30                     Spaghetti Bolognese
# 31                    Gino's Penne Alfredo
# 32                         Penne Calabrese
# 33                            Mac'n'Cheese
# 34                          Gino's Gnocchi
# 35                    Buffalo Ranch (30ml)
# 36         Sundried Tomato Marinara (30ml)
# 37                    Garlic & Herb (30ml)
# 38                BBQ Honey Mustard (30ml)
# 39                    Chipotle Mayo (30ml)
# 40                      Sweet Chili (30ml)
# 41                        Smoky BBQ (30ml)
# 42                       Marie Rose (30ml)
# 43                          Ginos Tiramisu
# 44                 Chocolate Fudge Brownie
# 45                  Banana Caramel Pudding
# 46                      Arwa Water (500ml)
# 47                       Coca Cola (250ml)
